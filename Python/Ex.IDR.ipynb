# %%
import pandas as pd

# %%
# Lendo base
data = pd.read_csv('dataIDR.csv', sep = ';')
# Quantidade de nulos por coluna
data.isnull().sum()
# Out:
# /home/logcomex/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# id                  0
# estacao_id          0
# data                0
# tempmax             0
# tempmin             0
# tempmed             0
# tempsec9            0
# tempsec15           0
# tempsec21           0
# tempumi9            0
# tempumi15           0
# tempumi21           0
# umid9               0
# umid15              0
# umid21              0
# umidrel             0
# vento10             0
# vento2              0
# chuva               0
# evaporacao          0
# insolacao           0
# radsolar            0
# create_user    453845
# update_user    453838
# create_time    453845
# update_time    453838
# dtype: int64

# %% [markdown]
# Colunas que possuem células em branco:
# * create_user
# * update_user
# * create_time
# * update_time
#
# Acredito que a melhor estratégia seja excluir todas essas colunas, pois representam uma perda muito pequena de informações em comparação ao tamanho da base, dado que encontram-se vazias para a maioria das linhas.
#
# No código abaixo as colunas citadas são excluídas:

# %%
data.drop(columns=['create_user', 'update_user', 'create_time', 'update_time'])
# Out:
#             id  estacao_id        data  tempmax  tempmin  tempmed  tempsec9  \
# 0          166     2548070  1977-11-01     25.0     19.8     21.7      22.2
# 1          167     2548070  1977-11-02     32.8     18.4     25.4      26.6
# 2          168     2548070  1977-11-03     29.0     20.4     23.3      23.4
# 3          169     2548070  1977-11-04     21.8     18.8     19.7      19.8
# 4          170     2548070  1977-11-05     25.2     18.6     20.6      19.8
# ...        ...         ...         ...      ...      ...      ...       ...
# 453840  464191     2653012  2019-12-27     33.4     19.0     26.4      26.2
# 453841  464192     2653012  2019-12-28     32.8     21.6     24.8      25.6
# 453842  464193     2653012  2019-12-29     35.2     18.6     27.0      26.4
# 453843  464194     2653012  2019-12-30     34.2     21.0     25.6      27.2
# 453844  464195     2653012  2019-12-31     33.2     19.4     25.0      24.8
#
# ...

# %%
from datetime import datetime

# %%
data1 = pd.read_csv('dataIDR.csv', sep = ';', index_col='data', parse_dates=True)
# Out:
# /home/logcomex/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 453845 entries, 1977-11-01 to 2019-12-31
# Data columns (total 25 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           453845 non-null  int64
#  1   estacao_id   453845 non-null  int64
#  2   tempmax      453845 non-null  float64
#  3   tempmin      453845 non-null  float64
#  4   tempmed      453845 non-null  float64
#  5   tempsec9     453845 non-null  float64
#  6   tempsec15    453845 non-null  float64
#  7   tempsec21    453845 non-null  float64
#  8   tempumi9     453845 non-null  float64
#  9   tempumi15    453845 non-null  float64
#  10  tempumi21    453845 non-null  float64
#  11  umid9        453845 non-null  float64
#  12  umid15       453845 non-null  float64
#  13  umid21       453845 non-null  float64
#  14  umidrel      453845 non-null  float64
#  15  vento10      453845 non-null  float64
#  16  vento2       453845 non-null  float64
# ...

# %%
data1.head()
# Out:
#              id  estacao_id  tempmax  tempmin  tempmed  tempsec9  tempsec15  \
# data
# 1977-11-01  166     2548070     25.0     19.8     21.7      22.2       23.6
# 1977-11-02  167     2548070     32.8     18.4     25.4      26.6       32.6
# 1977-11-03  168     2548070     29.0     20.4     23.3      23.4       25.8
# 1977-11-04  169     2548070     21.8     18.8     19.7      19.8       20.8
# 1977-11-05  170     2548070     25.2     18.6     20.6      19.8       21.4
#
#             tempsec21  tempumi9  tempumi15  ...  vento10  vento2  chuva  \
# data                                        ...
# 1977-11-01       20.8      18.6       22.0  ...      0.0     0.0    9.3
# 1977-11-02       24.6      22.8       24.4  ...      0.0     0.0   12.6
# 1977-11-03       21.8      21.6       23.2  ...      0.0     0.0    1.2
# 1977-11-04       19.0      19.2       19.4  ...      0.0     0.0   22.4
# 1977-11-05       19.6      18.8       20.4  ...      0.0     0.0   11.0
#
# ...

# %%
data1['2015-01-01':'2016-12-31']
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-b1aa5a1bee13> in <module>
# ----> 1 data1['2015-01-01':'2016-12-31']
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2883             # either we have a slice or we have a string that can be converted
#    2884             #  to a slice for partial-string date indexing
# -> 2885             return self._slice(indexer, axis=0)
#    2886
#    2887         # Do we have a (boolean) DataFrame?
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/generic.py in _slice(self, slobj, axis)
#    3552         Slicing with this method is *always* positional.
#    3553         """
# -> 3554         assert isinstance(slobj, slice), type(slobj)
#    3555         axis = self._get_block_manager_axis(axis)
# ...

# %%
# Criando função pra filtro de data
def filtro_data():
    d1 = input('Digite a data inicial no formato aaaa-mm-dd: ')
    d2 = input('Digite a data final no formato aaaa-mm-dd: ')
    filtro = data1[d1:d2]
    return filtro

filtro_data()
# Out:
# Digite a data inicial no formato aaaa-mm-dd: 2019-01-01
# Digite a data final no formato aaaa-mm-dd: 2019-05-01
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-31-1c17f239842a> in <module>
#       6     return sliced
#       7
# ----> 8 filtro_data()
#
# <ipython-input-31-1c17f239842a> in filtro_data()
#       3     d1 = input('Digite a data inicial no formato aaaa-mm-dd: ')
#       4     d2 = input('Digite a data final no formato aaaa-mm-dd: ')
# ----> 5     sliced = data1[d1:d2]
#       6     return sliced
#       7
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2883             # either we have a slice or we have a string that can be converted
#    2884             #  to a slice for partial-string date indexing
# -> 2885             return self._slice(indexer, axis=0)
#    2886
# ...
